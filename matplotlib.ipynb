# %%
import matplotlib 
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("jumta.csv")
df
# Out:
#        Month Revenue  Orders  Average_Order_Value
# 0   Jan-2020  10,000     200                   50
# 1   Feb-2020  11,000     220                   50
# 2   Mar-2020  12,000     240                   50
# 3   Apr-2020  13,000     260                   50
# 4   May-2020  14,000     280                   50
# 5   Jun-2020  15,000     300                   50
# 6   Jul-2020  16,000     320                   50
# 7   Aug-2020  17,000     340                   50
# 8   Sep-2020  18,000     360                   50
# 9   Oct-2020  19,000     380                   50
# 10  Nov-2020  20,000     400                   50
# 11  Dec-2020  21,000     420                   50
# 12  Jan-2021  22,000     440                   50
# 13  Feb-2021  23,000     460                   50
# 14  Mar-2021  24,000     480                   50
# 15  Apr-2021  25,000     500                   50
# 16  May-2021  26,000     520                   50
# 17  Jun-2021  27,000     540                   50
# ...

# %%
x = df.Month
y = df.Revenue

# Create a Figure and Axes
fig, ax = plt.subplots()

# Create line plots with labels for the legend
ax.plot(x, y1, label='Revenue')

# Add title and labels
ax.set_title('Line Plot')
ax.set_xlabel('Month')
ax.set_ylabel('Revenue')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %%
plt.bar(x,df.Orders)

# Add title and labels
plt.title('Bar Plot')

# Add a legend
ax.legend()


plt.show()

# %%
plt.scatter(df.Orders,df.Average_Order_Value)
plt.title('Scatter plot')
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, sharex=True)
y1 = df.Revenue
y2 = df.Orders
y3 = df.Average_Order_Value
ax1.plot(x, y1)
ax1.set_title('Line')

ax2.bar(x, y2)
ax2.set_title('Bar')

ax3.scatter(df.Orders, y3)
ax3.set_title('Scatter')

plt.show()

# %%
plt.savefig('summary.png', dpi=300)
